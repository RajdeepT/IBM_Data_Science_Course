# %% [markdown]
# # Interactive Map using Folium
#
# This notebook generates an interactive map to visualize SpaceX launch sites and outcomes.
#
# ## Objectives:
# - Plot global launch site locations.
# - Visualize launch outcome using colored markers.
# - Show proximities (railways, coastlines, etc.) from selected launch site.

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import folium
from folium import plugins

# %% [markdown]
# ## Step 1: Create a mapping of known SpaceX launch sites to their coordinates

# %%
# Load your cleaned dataset
df = pd.read_csv("spacex_clean_data.csv")

# Define a dictionary with known SpaceX launch site coordinates
site_coords = {
    'Cape Canaveral, SLC‑40': (28.5618571, -80.577366),
    'Kennedy, LC‑39A': (28.6080585, -80.6039558),
    'Vandenberg, SLC‑4E': (34.6328344, -120.6107465),
    'Vandenberg, SLC‑4W': (34.633, -120.61),  # Historic pad
    'Vandenberg, SLC-6': (34.576, -120.629),
    'Cape Canaveral, LC-13': (28.485833, -80.544444),
    'Cape Canaveral, LC-36A': (28.508, -80.55),
    'Boca Chica': (25.997, -97.156)
}

# %% [markdown]
# ## Step 2: Map the coordinates into your DataFrame

# %%
# Map latitude and longitude from launch_site column
df['latitude'] = df['launch_site'].map(lambda x: site_coords.get(x, (None, None))[0])
df['longitude'] = df['launch_site'].map(lambda x: site_coords.get(x, (None, None))[1])

# Drop rows with unknown coordinates (if any)
df = df.dropna(subset=['latitude', 'longitude'])

# Preview updated DataFrame
df[['launch_site', 'latitude', 'longitude']].drop_duplicates()
df.to_csv("spacex_clean_data_with_coordinates.csv", index=False)
print("✅ Updated dataset saved with coordinates!")
df.head()
# Out:
# ✅ Updated dataset saved with coordinates!
#   flight_no.         date_and_time_(utc)           version,_booster[h]  \
# 0        195   January 3, 2023 14:56[17]                F9 B5 B1060‑15
# 1        196  January 10, 2023 04:50[23]                 F9 B5 B1076‑2
# 2       FH 5  January 15, 2023 22:56[29]  Falcon Heavy B5 B1070 (core)
# 3        197  January 18, 2023 12:24[33]                 F9 B5 B1077‑2
# 4        198  January 19, 2023 15:43[39]                 F9 B5 B1075‑1
#
#               launch_site                                      payload[i]  \
# 0  Cape Canaveral, SLC‑40  Transporter-6 (115 payload smallsat rideshare)
# 1  Cape Canaveral, SLC‑40                       OneWeb 16 (40 satellites)
# 2         Kennedy, LC‑39A                      USSF-67 (CBAS-2 & LDPE-3A)
# 3  Cape Canaveral, SLC‑40                          USA-343 (GPS-III SV06)
# 4      Vandenberg, SLC‑4E             Starlink: Group 2-4 (51 satellites)
#
#             payload_mass      orbit customer launch_outcome   booster_landing  \
# 0             Unknown[j]        SSO  Various        Success    Success (LZ‑1)
# 1   6,000 kg (13,000 lb)  Polar LEO   OneWeb        Success    Success (LZ‑1)
# 2   ~3,750 kg (8,270 lb)        GEO     USSF        Success        No attempt
# 3    4,352 kg (9,595 lb)        MEO     USSF        Success    Success (JRTI)
# 4  15,000 kg (33,000 lb)        LEO   SpaceX        Success  Success (OCISLY)
#
#     latitude   longitude
# 0  28.561857  -80.577366
# 1  28.561857  -80.577366
# 2  28.608058  -80.603956
# 3  28.561857  -80.577366
# 4  34.632834 -120.610747

# %% [markdown]
# ## Map 1: All Launch Sites with Location Markers

# %%
# Map 1: All Launch Sites
site_map = folium.Map(location=[28.563197, -80.576820], zoom_start=3)

for _, row in df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['launch_site'],
        icon=folium.Icon(color='blue', icon='rocket', prefix='fa')
    ).add_to(site_map)

site_map.save("folium_launch_sites_map.html")
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_72566c838b2476a7fe4588c389a8438c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_72566c838b2476a7fe4588c389a8438c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_72566c838b2476a7fe4588c389a8438c = L.map(
#                 &quot;map_72566c838b2476a7fe4588c389a8438c&quot;,
#                 {
#                     center: [28.563197, -80.57682],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61ae8111c36c1b95f9fe2f4e14e44030 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61ae8111c36c1b95f9fe2f4e14e44030.addTo(map_72566c838b2476a7fe4588c389a8438c);
#
#
#             var marker_099d5b345caf798cefe830b0651b2241 = L.marker(
#                 [28.5618571, -80.577366],
#                 {
# }
#             ).addTo(map_72566c838b2476a7fe4588c389a8438c);
#
#
#             var icon_80dbdb73727fd40a2bf4f5f48baba7e4 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_99598ebc08f4fe9123c3c451401ad439 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42e78ec1dc791d66c86d11aecaa4549e = $(`&lt;div id=&quot;html_42e78ec1dc791d66c86d11aecaa4549e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cape Canaveral, SLC‑40&lt;/div&gt;`)[0];
#                 popup_99598ebc08f4fe9123c3c451401ad439.setContent(html_42e78ec1dc791d66c86d11aecaa4549e);
#
#
#
#         marker_099d5b345caf798cefe830b0651b2241.bindPopup(popup_99598ebc08f4fe9123c3c451401ad439)
#         ;
#
#
#
#
#                 marker_099d5b345caf798cefe830b0651b2241.setIcon(icon_80dbdb73727fd40a2bf4f5f48baba7e4);
#
#
#             var marker_af83c1cebc357b2fa6e97fa24746faed = L.marker(
#                 [28.5618571, -80.577366],
#                 {
# }
#             ).addTo(map_72566c838b2476a7fe4588c389a8438c);
#
#
#             var icon_8d81f0d6fac6552fec0ddc55c2b4b254 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a9a654389018c330a06874e2468e1417 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e73a3971bd64238c3e7276340a63fa03 = $(`&lt;div id=&quot;html_e73a3971bd64238c3e7276340a63fa03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cape Canaveral, SLC‑40&lt;/div&gt;`)[0];
#                 popup_a9a654389018c330a06874e2468e1417.setContent(html_e73a3971bd64238c3e7276340a63fa03);
#
#
#
#         marker_af83c1cebc357b2fa6e97fa24746faed.bindPopup(popup_a9a654389018c330a06874e2468e1417)
#         ;
#
#
#
#
#                 marker_af83c1cebc357b2fa6e97fa24746faed.setIcon(icon_8d81f0d6fac6552fec0ddc55c2b4b254);
#
#
#             var marker_dc48dc0bee51dae2952b99f546c3e409 = L.marker(
#                 [28.6080585, -80.6039558],
#                 {
# }
#             ).addTo(map_72566c838b2476a7fe4588c389a8438c);
#
#
#             var icon_51ff4ea8aaed35784348b96dcf80c8aa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_99bd0ae41884b57de914ece529b5e7e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb36e2bd91afc0e9d423777c40fb33ff = $(`&lt;div id=&quot;html_bb36e2bd91afc0e9d423777c40fb33ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kennedy, LC‑39A&lt;/div&gt;`)[0];
#                 popup_99bd0ae41884b57de914ece529b5e7e3.setContent(html_bb36e2bd91afc0e9d423777c40fb33ff);
#
#
#
#         marker_dc48dc0bee51dae2952b99f546c3e409.bindPopup(popup_99bd0ae41884b57de914ece529b5e7e3)
#         ;
#
#
#
#
#                 marker_dc48dc0bee51dae2952b99f546c3e409.setIcon(icon_51ff4ea8aaed35784348b96dcf80c8aa);
#
#
#             var marker_0891a757cf818bd7ebea5f05d

# %% [markdown]
# ## Map 2: Launch Outcomes with Colored Markers

# %%
# Map 2: Outcome markers with color
outcome_map = folium.Map(location=[28.563197, -80.576820], zoom_start=3)

def color(success):
    if "Success" in str(success):
        return 'green'
    elif "Failure" in str(success):
        return 'red'
    else:
        return 'gray'

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=6,
        color=color(row.get('booster_landing', 'None')),
        fill=True,
        fill_opacity=0.7,
        popup=row.get('booster_landing', 'N/A')
    ).add_to(outcome_map)

outcome_map.save("folium_outcome_map.html")
outcome_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d058a9409a134d2c3d431fd592a703bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d058a9409a134d2c3d431fd592a703bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d058a9409a134d2c3d431fd592a703bf = L.map(
#                 &quot;map_d058a9409a134d2c3d431fd592a703bf&quot;,
#                 {
#                     center: [28.563197, -80.57682],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7fa976f1143b04feb2dd802a6ed1153 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7fa976f1143b04feb2dd802a6ed1153.addTo(map_d058a9409a134d2c3d431fd592a703bf);
#
#
#             var circle_marker_2d8135854fce33a3d122e1d7c10cacbb = L.circleMarker(
#                 [28.5618571, -80.577366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d058a9409a134d2c3d431fd592a703bf);
#
#
#         var popup_88deb285832c4476d1b8394be2932e35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c79bfdce49f57a3c071c48e6b48f3014 = $(`&lt;div id=&quot;html_c79bfdce49f57a3c071c48e6b48f3014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Success (LZ‑1)&lt;/div&gt;`)[0];
#                 popup_88deb285832c4476d1b8394be2932e35.setContent(html_c79bfdce49f57a3c071c48e6b48f3014);
#
#
#
#         circle_marker_2d8135854fce33a3d122e1d7c10cacbb.bindPopup(popup_88deb285832c4476d1b8394be2932e35)
#         ;
#
#
#
#
#             var circle_marker_19a286b78d276bcb3e41fa3da05f9a40 = L.circleMarker(
#                 [28.5618571, -80.577366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d058a9409a134d2c3d431fd592a703bf);
#
#
#         var popup_1e41d0389e8fd44f40eff03b176313a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee5b84d66e57fcd2a52fc940f22087ab = $(`&lt;div id=&quot;html_ee5b84d66e57fcd2a52fc940f22087ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Success (LZ‑1)&lt;/div&gt;`)[0];
#                 popup_1e41d0389e8fd44f40eff03b176313a3.setContent(html_ee5b84d66e57fcd2a52fc940f22087ab);
#
#
#
#         circle_marker_19a286b78d276bcb3e41fa3da05f9a40.bindPopup(popup_1e41d0389e8fd44f40eff03b176313a3)
#         ;
#
#
#
#
#             var circle_marker_a7f8a7be514e64b8d1b6edc769d3bfce = L.circleMarker(
#                 [28.6080585, -80.6039558],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d058a9409a134d2c3d431fd592a703bf);
#
#
#         var popup_06e1396f198af695ff45d487b78b6a49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad4721348518915569cafa624e875f51 = $(`&lt;div id=&quot;html_ad4721348518915569cafa624e875f51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No attempt&lt;/div&gt;`)[0];
#                 popup_06e1396f198af695ff45d487b78b6a49.setContent(html_ad4721348518915569cafa624e875f51);
#
#
#
#         circle_marker_a7f8a7be514e64b8d1b6edc769d3bfce.bindPopup(popup_06e1396f198af695ff45d487b78b6a49)
#         ;
#
#
#
#
#             var circle_marker_0b8875ec36655d0882f12fa040af8204 = L.c

# %% [markdown]
# ## Map 3: Proximity of Launch Site to Key Features

# %%
# Map 3: Proximity map (static example)
selected = df[df['launch_site'].str.contains("Cape Canaveral", na=False)].iloc[0]

prox_map = folium.Map(location=[selected['latitude'], selected['longitude']], zoom_start=10)

# Launch Site marker
folium.Marker([selected['latitude'], selected['longitude']], popup="Launch Site").add_to(prox_map)

# 5 km Circle around launch site
folium.Circle([selected['latitude'], selected['longitude']], radius=5000, color='blue', fill=False).add_to(prox_map)

# Simulated Nearby Highway
folium.Marker([selected['latitude'] + 0.03, selected['longitude']], popup="Nearby Highway").add_to(prox_map)

# Simulated Nearby Coastline
folium.Marker([selected['latitude'], selected['longitude'] + 0.03], popup="Nearby Coastline").add_to(prox_map)

prox_map.save("folium_proximity_map.html")
prox_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_657792bc9acf1ce4dbe5d755d5b8ca00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_657792bc9acf1ce4dbe5d755d5b8ca00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_657792bc9acf1ce4dbe5d755d5b8ca00 = L.map(
#                 &quot;map_657792bc9acf1ce4dbe5d755d5b8ca00&quot;,
#                 {
#                     center: [28.5618571, -80.577366],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdf13c2385e2dae97cf19c62790a0cb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fdf13c2385e2dae97cf19c62790a0cb6.addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
#
#             var marker_85e573951ae86923c98d653f6729b282 = L.marker(
#                 [28.5618571, -80.577366],
#                 {
# }
#             ).addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
#
#         var popup_b8ccd1b8216e108853cc1e814dd56c66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4f04bf9927fb8a578ae9950815cc96d = $(`&lt;div id=&quot;html_f4f04bf9927fb8a578ae9950815cc96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_b8ccd1b8216e108853cc1e814dd56c66.setContent(html_f4f04bf9927fb8a578ae9950815cc96d);
#
#
#
#         marker_85e573951ae86923c98d653f6729b282.bindPopup(popup_b8ccd1b8216e108853cc1e814dd56c66)
#         ;
#
#
#
#
#             var circle_dd8ffeb1932887bd8a1e82e9a9401b60 = L.circle(
#                 [28.5618571, -80.577366],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
#
#             var marker_591eb0e7251b16c065ec1faf047c4b27 = L.marker(
#                 [28.591857100000002, -80.577366],
#                 {
# }
#             ).addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
#
#         var popup_7ce1508686e8cf81a56c9de250443b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ab6c30193ca259c3d53bb47d087a75e = $(`&lt;div id=&quot;html_4ab6c30193ca259c3d53bb47d087a75e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nearby Highway&lt;/div&gt;`)[0];
#                 popup_7ce1508686e8cf81a56c9de250443b4b.setContent(html_4ab6c30193ca259c3d53bb47d087a75e);
#
#
#
#         marker_591eb0e7251b16c065ec1faf047c4b27.bindPopup(popup_7ce1508686e8cf81a56c9de250443b4b)
#         ;
#
#
#
#
#             var marker_fa929cc14fe5826a4178b1ace4631fb9 = L.marker(
#                 [28.5618571, -80.547366],
#                 {
# }
#             ).addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
#
#         var popup_548949ed13b1dcf74ec884707d03982d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2d785ae5f64cb705409830759187a65 = $(`&lt;div id=&quot;html_f2d785ae5f64cb705409830759187a65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nearby Coastline&lt;/div&gt;`)[0];
#                 popup_548949ed13b1dcf74ec884707d03982d.setContent(html_f2d785ae5f64cb705409830759187a65);
#
#
#
#         marker_fa929cc14fe5826a4178b1ace4631fb9.bindPopup(popup_548949ed13b1dcf74ec884707d03982d)
#         ;
#
#
#
#
#             tile_layer_fdf13c2385e2dae97cf19c62790a0cb6.addTo(map_657792bc9acf1ce4dbe5d755d5b8ca00);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
